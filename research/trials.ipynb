# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x: int, y: int) -> int:
    return x*y

# %%
get_product(1,3)
# Out:
# 3

# %%
get_product(2,"gg")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_product(2,"gg")
#
# File d:\ml\deepCNN_Classifier\env\lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000001FC1430C550> does not match annotation type <class 'int'>

# %%
def get_product(x: int, y: int) -> int:
    return x*y

# %%
get_product(2,"gg")
# Out:
# 'gggg'

# %%
# !nvidia-smi
# Out:
# Mon Jan 30 18:25:08 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 527.56       Driver Version: 527.56       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   46C    P0    14W /  50W |      0MiB /  4096MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf

# %%
tf.test.is_built_with_cuda()
# Out:
# False

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\nites\AppData\Local\Temp\ipykernel_30188\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
conda install -c conda-forge cudatoolkit=11.2 cudnn=8.1.0
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done

# %%
tf.__version__
# Out:
# '2.11.0'

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\nites\miniconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-client-1.11.0     |   py39haa95532_0         165 KB
#     attrs-22.1.0               |   py39haa95532_0          84 KB
#     certifi-2022.12.7          |   py39haa95532_0         149 KB
#     cffi-1.15.1                |   py39h2bbff1b_3         238 KB
#     chardet-4.0.0              |py39haa95532_1003         212 KB
#     clyent-1.2.2               |   py39haa95532_1          21 KB
#     colorama-0.4.6             |   py39haa95532_0          32 KB
#     conda-23.1.0               |   py39haa95532_0         946 KB
#     conda-content-trust-0.1.3  |   py39haa95532_0          86 KB
#     conda-package-handling-2.0.2|   py39haa95532_0         286 KB
#     conda-package-streaming-0.7.0|   py39haa95532_0          27 KB
#     conda-repo-cli-1.0.27      |   py39haa95532_0         130 KB
#     conda-token-0.4.0          |     pyhd3eb1b0_0          13 KB
#     cryptography-38.0.4        |   py39h21b164f_0         1.0 MB
#     freetype-2.12.1            |       ha860e81_0         490 KB
#     glib-2.69.1                |       h5dc1a3c_2         1.8 MB
#     gst-plugins-base-1.18.5    |       h9e645db_0         1.7 MB
#     gstreamer-1.18.5           |       hd78058f_0         1.7 MB
#     idna-3.4                   |   py39haa95532_0          93 KB
#     jpeg-9e                    |       h2bbff1b_0         292 KB
#     jsonschema-4.16.0          |   py39haa95532_0         143 KB
#     jupyter_core-5.1.1         |   py39haa95532_0         107 KB
#     lerc-3.0                   |       hd77b12b_0         120 KB
#     libclang-12.0.0            |default_h627e005_2        17.8 MB
#     libdeflate-1.8             |       h2bbff1b_5          46 KB
#     libiconv-1.16              |       h2bbff1b_2         651 KB
#     libogg-1.3.5               |       h2bbff1b_1          33 KB
#     libpng-1.6.37              |       h2a8f88b_0         333 KB
#     libtiff-4.5.0              |       h8a3f274_0         1.2 MB
#     libvorbis-1.3.7            |       he774522_0         202 KB
#     libwebp-1.2.4              |       h2bbff1b_0          67 KB
#     libwebp-base-1.2.4         |       h2bbff1b_0         279 KB
#     libxml2-2.9.14             |       h0ad7f3c_0         1.5 MB
#     libxslt-1.1.35             |       h2bbff1b_0         407 KB
#     lz4-c-1.9.4                |       h2bbff1b_0         143 KB
#     navigator-updater-0.3.0    |   py39haa95532_0         2.2 MB
#     nbformat-5.7.0             |   py39haa95532_0         152 KB
#     packaging-22.0             |   py39haa95532_0          67 KB
#     pathlib-1.0.1              |     pyhd3eb1b0_1          17 KB
#     pcre-8.45                  |       hd77b12b_0         382 KB
#     pillow-9.3.0               |   py39hdc2b20a_1         994 KB
#     pip-22.3.1                 |   py39haa95532_0         2.7 MB
#     platformdirs-2.5.2         |   py39haa95532_0          24 KB
#     pluggy-1.0.0               |   py39haa95532_1          29 KB
#     ply-3.11                   |   py39haa95532_0          81 KB
#     psutil-5.9.0               |   py39h2bbff1b_0         349 KB
#     pycosat-0.6.4              |   py39h2bbff1b_0          74 KB
#     pyjwt-2.4.0                |   py39haa95532_0          38 KB
#     pyqt-5.15.7                |   py39hd77b12b_0         3.7 MB
#     pyqt5-sip-12.11.0          |   py39hd77b12b_0          75 KB
#     pyrsistent-0.18.0          |   py39h196d8e1_0          90 KB
#     python-fastjsonschema-2.16.2|   py39haa95532_0         231 KB
#     pytz-2022.7                |   py39haa95532_0         210 KB
#     pywin32-305                |   py39h2bbff1b_0        10.7 MB
#     pyyaml-6.0                 |   py39h2bbff1b_1         145 KB
#     qt-main-5.15.2             |       he8e5bd7_7        50.0 MB
#     qt-webengine-5.15.9        |       hb9a9bb5_5        48.9 MB
#     qtpy-2.2.0                 |   py39haa95532_0         106 KB
#     qtwebkit-5.212             |       h3ad3cdb_4        10.3 MB
#     requests-2.28.1            |   py39haa95532_0          99 KB
#     ruamel.yaml-0.17.21        |   py39h2bbff1b_0         174 KB
#     ruamel.yaml.clib-0.2.6     |   py39h2bbff1b_1         101 KB
#     setuptools-65.6.3          |   py39haa95532_0         1.1 MB
#     sip-6.6.2                  |   py39hd77b12b_0         434 KB
#     toml-0.10.2                |     pyhd3eb1b0_0          20 KB
#     tqdm-4.64.1                |   py39haa95532_0         143 KB
#     traitlets-5.7.1            |   py39haa95532_0         205 KB
#     tzdata-2022g               |       h04d1e81_0         114 KB
#     ujson-5.4.0                |   py39hd77b12b_0          44 KB
#     urllib3-1.26.14            |   py39haa95532_0         193 KB
#     xz-5.2.10                  |       h8cc25b3_1         520 KB
#     zstandard-0.18.0           |   py39h2bbff1b_0         310 KB
#     zstd-1.5.2                 |       h19a0ad4_0         509 KB
#     ------------------------------------------------------------
#                                            Total:       167.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   colorama           pkgs/main/win-64::colorama-0.4.6-py39haa95532_0 None
#   conda-package-str~ pkgs/main/win-64::conda-package-streaming-0.7.0-py39haa95532_0 None
#   glib               pkgs/main/win-64::glib-2.69.1-h5dc1a3c_2 None
#   gst-plugins-base   pkgs/main/win-64::gst-plugins-base-1.18.5-h9e645db_0 None
#   gstreamer          pkgs/main/win-64::gstreamer-1.18.5-hd78058f_0 None
#   lerc               pkgs/main/win-64::lerc-3.0-hd77b12b_0 None
#   libclang           pkgs/main/win-64::libclang-12.0.0-default_h627e005_2 None
#   libdeflate         pkgs/main/win-64::libdeflate-1.8-h2bbff1b_5 None
#   libffi             pkgs/main/win-64::libffi-3.4.2-hd77b12b_6 None
#   libiconv           pkgs/main/win-64::libiconv-1.16-h2bbff1b_2 None
#   libogg             pkgs/main/win-64::libogg-1.3.5-h2bbff1b_1 None
#   libvorbis          pkgs/main/win-64::libvorbis-1.3.7-he774522_0 None
#   libwebp-base       pkgs/main/win-64::libwebp-base-1.2.4-h2bbff1b_0 None
#   libxml2            pkgs/main/win-64::libxml2-2.9.14-h0ad7f3c_0 None
#   libxslt            pkgs/main/win-64::libxslt-1.1.35-h2bbff1b_0 None
#   pathlib            pkgs/main/noarch::pathlib-1.0.1-pyhd3eb1b0_1 None
#   pcre               pkgs/main/win-64::pcre-8.45-hd77b12b_0 None
#   platformdirs       pkgs/main/win-64::platformdirs-2.5.2-py39haa95532_0 None
#   pluggy             pkgs/main/win-64::pluggy-1.0.0-py39haa95532_1 None
#   ply                pkgs/main/win-64::ply-3.11-py39haa95532_0 None
#   pyqt5-sip          pkgs/main/win-64::pyqt5-sip-12.11.0-py39hd77b12b_0 None
#   qt-main            pkgs/main/win-64::qt-main-5.15.2-he8e5bd7_7 None
#   qt-webengine       pkgs/main/win-64::qt-webengine-5.15.9-hb9a9bb5_5 None
#   qtwebkit           pkgs/main/win-64::qtwebkit-5.212-h3ad3cdb_4 None
#   ruamel.yaml        pkgs/main/win-64::ruamel.yaml-0.17.21-py39h2bbff1b_0 None
#   ruamel.yaml.clib   pkgs/main/win-64::ruamel.yaml.clib-0.2.6-py39h2bbff1b_1 None
#   toml               pkgs/main/noarch::toml-0.10.2-pyhd3eb1b0_0 None
#   zstandard          pkgs/main/win-64::zstandard-0.18.0-py39h2bbff1b_0 None
#
# The following packages will be REMOVED:
#
#   pyparsing-3.0.4-pyhd3eb1b0_0
#   qt-5.9.7-vc14h73c81de_0
#   ruamel_yaml-0.15.100-py39h2bbff1b_0
#
# The following packages will be UPDATED:
#
#   anaconda-client    anaconda::anaconda-client-1.10.0-py39~ --> pkgs/main::anaconda-client-1.11.0-py39haa95532_0 None
#   attrs              anaconda/noarch::attrs-21.4.0-pyhd3eb~ --> pkgs/main/win-64::attrs-22.1.0-py39haa95532_0 None
#   ca-certificates                     2022.10.11-haa95532_0 --> 2023.01.10-haa95532_0 None
#   certifi                          2022.9.24-py39haa95532_0 --> 2022.12.7-py39haa95532_0 None
#   cffi                                1.15.0-py39h2bbff1b_0 --> 1.15.1-py39h2bbff1b_3 None
#   conda                               22.9.0-py39haa95532_0 --> 23.1.0-py39haa95532_0 None
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust~ --> pkgs/main/win-64::conda-content-trust-0.1.3-py39haa95532_0 None
#   conda-package-han~                   1.7.3-py39h8cc25b3_1 --> 2.0.2-py39haa95532_0 None
#   conda-repo-cli     anaconda/noarch::conda-repo-cli-1.0.4~ --> pkgs/main/win-64::conda-repo-cli-1.0.27-py39haa95532_0 None
#   conda-token        anaconda::conda-token-0.3.0-pyhd3eb1b~ --> pkgs/main::conda-token-0.4.0-pyhd3eb1b0_0 None
#   cryptography       anaconda::cryptography-3.4.8-py39h71e~ --> pkgs/main::cryptography-38.0.4-py39h21b164f_0 None
#   freetype             anaconda::freetype-2.10.4-hd328e21_0 --> pkgs/main::freetype-2.12.1-ha860e81_0 None
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0~ --> pkgs/main/win-64::idna-3.4-py39haa95532_0 None
#   jsonschema         anaconda::jsonschema-4.4.0-py39haa955~ --> pkgs/main::jsonschema-4.16.0-py39haa95532_0 None
#   jupyter_core       anaconda::jupyter_core-4.10.0-py39haa~ --> pkgs/main::jupyter_core-5.1.1-py39haa95532_0 None
#   libtiff                anaconda::libtiff-4.2.0-he0120a3_1 --> pkgs/main::libtiff-4.5.0-h8a3f274_0 None
#   libwebp                anaconda::libwebp-1.2.2-h2bbff1b_0 --> pkgs/main::libwebp-1.2.4-h2bbff1b_0 None
#   lz4-c                    anaconda::lz4-c-1.9.3-h2bbff1b_1 --> pkgs/main::lz4-c-1.9.4-h2bbff1b_0 None
#   navigator-updater  anaconda::navigator-updater-0.2.1-py3~ --> pkgs/main::navigator-updater-0.3.0-py39haa95532_0 None
#   nbformat           anaconda::nbformat-5.3.0-py39haa95532~ --> pkgs/main::nbformat-5.7.0-py39haa95532_0 None
#   packaging          anaconda/noarch::packaging-21.3-pyhd3~ --> pkgs/main/win-64::packaging-22.0-py39haa95532_0 None
#   pillow              anaconda::pillow-9.0.1-py39hdc2b20a_0 --> pkgs/main::pillow-9.3.0-py39hdc2b20a_1 None
#   pip                                 21.2.4-py39haa95532_0 --> 22.3.1-py39haa95532_0 None
#   psutil              anaconda::psutil-5.8.0-py39h2bbff1b_1 --> pkgs/main::psutil-5.9.0-py39h2bbff1b_0 None
#   pycosat                              0.6.3-py39h2bbff1b_0 --> 0.6.4-py39h2bbff1b_0 None
#   pyjwt                anaconda::pyjwt-2.1.0-py39haa95532_0 --> pkgs/main::pyjwt-2.4.0-py39haa95532_0 None
#   pyopenssl                             21.0.0-pyhd3eb1b0_1 --> 22.0.0-pyhd3eb1b0_0 None
#   pyqt                  anaconda::pyqt-5.9.2-py39hd77b12b_6 --> pkgs/main::pyqt-5.15.7-py39hd77b12b_0 None
#   python-fastjsonsc~ anaconda/noarch::python-fastjsonschem~ --> pkgs/main/win-64::python-fastjsonschema-2.16.2-py39haa95532_0 None
#   pytz                 anaconda::pytz-2022.1-py39haa95532_0 --> pkgs/main::pytz-2022.7-py39haa95532_0 None
#   pywin32                                302-py39h827c3e9_1 --> 305-py39h2bbff1b_0 None
#   qtpy               anaconda/noarch::qtpy-2.0.1-pyhd3eb1b~ --> pkgs/main/win-64::qtpy-2.2.0-py39haa95532_0 None
#   requests           pkgs/main/noarch::requests-2.27.1-pyh~ --> pkgs/main/win-64::requests-2.28.1-py39haa95532_0 None
#   setuptools                          58.0.4-py39haa95532_0 --> 65.6.3-py39haa95532_0 None
#   sip                  anaconda::sip-4.19.13-py39hd77b12b_0 --> pkgs/main::sip-6.6.2-py39hd77b12b_0 None
#   six                                   1.16.0-pyhd3eb1b0_0 --> 1.16.0-pyhd3eb1b0_1 None
#   sqlite                                  3.37.0-h2bbff1b_0 --> 3.40.1-h2bbff1b_0 None
#   tqdm               pkgs/main/noarch::tqdm-4.62.3-pyhd3eb~ --> pkgs/main/win-64::tqdm-4.64.1-py39haa95532_0 None
#   traitlets          anaconda/noarch::traitlets-5.1.1-pyhd~ --> pkgs/main/win-64::traitlets-5.7.1-py39haa95532_0 None
#   tzdata                                   2021e-hda174b7_0 --> 2022g-h04d1e81_0 None
#   ujson                anaconda::ujson-5.1.0-py39hd77b12b_0 --> pkgs/main::ujson-5.4.0-py39hd77b12b_0 None
#   urllib3            pkgs/main/noarch::urllib3-1.26.7-pyhd~ --> pkgs/main/win-64::urllib3-1.26.14-py39haa95532_0 None
#   xz                          anaconda::xz-5.2.5-h8cc25b3_1 --> pkgs/main::xz-5.2.10-h8cc25b3_1 None
#   zlib                     anaconda::zlib-1.2.12-h8cc25b3_2 --> pkgs/main::zlib-1.2.13-h8cc25b3_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   chardet                                          anaconda --> pkgs/main None
#   clyent                                           anaconda --> pkgs/main None
#   jpeg                                             anaconda --> pkgs/main None
#   libpng                                           anaconda --> pkgs/main None
#   pyrsistent                                       anaconda --> pkgs/main None
#   python-dateutil                                  anaconda --> pkgs/main None
#   pyyaml                                           anaconda --> pkgs/main None
#   tk                                               anaconda --> pkgs/main None
#   zstd                                             anaconda --> pkgs/main None
#
#
#
# Downloading and Extracting Packages
#
# python-fastjsonschem | 231 KB    |            |   0%
# python-fastjsonschem | 231 KB    | 6          |   7%
# python-fastjsonschem | 231 KB    | ########## | 100%
# python-fastjsonschem | 231 KB    | ########## | 100%
#
# ujson-5.4.0          | 44 KB     |            |   0%
# ujson-5.4.0          | 44 KB     | ########## | 100%
# ujson-5.4.0          | 44 KB     | ########## | 100%
#
# platformdirs-2.5.2   | 24 KB     |            |   0%
# platformdirs-2.5.2   | 24 KB     | ######7    |  67%
# platformdirs-2.5.2   | 24 KB     | ########## | 100%
#
# pillow-9.3.0         | 994 KB    |            |   0%
# pillow-9.3.0         | 994 KB    | ##8        |  29%
# pillow-9.3.0         | 994 KB    | ########6  |  87%
# pillow-9.3.0         | 994 KB    | ########## | 100%
#
# libdeflate-1.8       | 46 KB     |            |   0%
# libdeflate-1.8       | 46 KB     | ########## | 100%
# libdeflate-1.8       | 46 KB     | ########## | 100%
#
# pluggy-1.0.0         | 29 KB     |            |   0%
# pluggy-1.0.0         | 29 KB     | #####5     |  55%
# pluggy-1.0.0         | 29 KB     | ########## | 100%
# pluggy-1.0.0         | 29 KB     | ########## | 100%
#
# ruamel.yaml.clib-0.2 | 101 KB    |            |   0%
# ruamel.yaml.clib-0.2 | 101 KB    | ########## | 100%
# ruamel.yaml.clib-0.2 | 101 KB    | ########## | 100%
#
# ply-3.11             | 81 KB     |            |   0%
# ply-3.11             | 81 KB     | ########## | 100%
# ply-3.11             | 81 KB     | ########## | 100%
#
# psutil-5.9.0         | 349 KB    |            |   0%
# psutil-5.9.0         | 349 KB    | 4          |   5%
# psutil-5.9.0         | 349 KB    | 9          |   9%
# psutil-5.9.0         | 349 KB    | #8         |  18%
# psutil-5.9.0         | 349 KB    | #####4     |  55%
# psutil-5.9.0         | 349 KB    | ########## | 100%
# psutil-5.9.0         | 349 KB    | ########## | 100%
#
# conda-token-0.4.0    | 13 KB     |            |   0%
# conda-token-0.4.0    | 13 KB     | ########## | 100%
# conda-token-0.4.0    | 13 KB     | ########## | 100%
#
# idna-3.4             | 93 KB     |            |   0%
# idna-3.4             | 93 KB     | ########5  |  86%
# idna-3.4             | 93 KB     | ########## | 100%
#
# glib-2.69.1          | 1.8 MB    |            |   0%
# glib-2.69.1          | 1.8 MB    | 3          |   4%
# glib-2.69.1          | 1.8 MB    | #4         |  15%
# glib-2.69.1          | 1.8 MB    | ##6        |  26%
# glib-2.69.1          | 1.8 MB    | ###9       |  40%
# glib-2.69.1          | 1.8 MB    | #####3     |  54%
# glib-2.69.1          | 1.8 MB    | ######8    |  69%
# glib-2.69.1          | 1.8 MB    | ########5  |  85%
# glib-2.69.1          | 1.8 MB    | ########## | 100%
# glib-2.69.1          | 1.8 MB    | ########## | 100%
#
# urllib3-1.26.14      | 193 KB    |            |   0%
# urllib3-1.26.14      | 193 KB    | #####7     |  58%
# urllib3-1.26.14      | 193 KB    | ########## | 100%
#
# sip-6.6.2            | 434 KB    |            |   0%
# sip-6.6.2            | 434 KB    | #8         |  18%
# sip-6.6.2            | 434 KB    | #########2 |  92%
# sip-6.6.2            | 434 KB    | ########## | 100%
#
# certifi-2022.12.7    | 149 KB    |            |   0%
# certifi-2022.12.7    | 149 KB    | ########5  |  86%
# certifi-2022.12.7    | 149 KB    | ########## | 100%
#
# jpeg-9e              | 292 KB    |            |   0%
# jpeg-9e              | 292 KB    | ##7        |  27%
# jpeg-9e              | 292 KB    | ########## | 100%
# jpeg-9e              | 292 KB    | ########## | 100%
#
# colorama-0.4.6       | 32 KB     |            |   0%
# colorama-0.4.6       | 32 KB     | ########## | 100%
# colorama-0.4.6       | 32 KB     | ########## | 100%
#
# libxml2-2.9.14       | 1.5 MB    |            |   0%
# libxml2-2.9.14       | 1.5 MB    | 8          |   8%
# libxml2-2.9.14       | 1.5 MB    | ##8        |  28%
# libxml2-2.9.14       | 1.5 MB    | ######2    |  62%
# libxml2-2.9.14       | 1.5 MB    | #########1 |  92%
# libxml2-2.9.14       | 1.5 MB    | ########## | 100%
#
# libogg-1.3.5         | 33 KB     |            |   0%
# libogg-1.3.5         | 33 KB     | ########## | 100%
# libogg-1.3.5         | 33 KB     | ########## | 100%
#
# attrs-22.1.0         | 84 KB     |            |   0%
# attrs-22.1.0         | 84 KB     | ########## | 100%
# attrs-22.1.0         | 84 KB     | ########## | 100%
#
# conda-repo-cli-1.0.2 | 130 KB    |            |   0%
# conda-repo-cli-1.0.2 | 130 KB    | ########## | 100%
# conda-repo-cli-1.0.2 | 130 KB    | ########## | 100%
#
# anaconda-client-1.11 | 165 KB    |            |   0%
# anaconda-client-1.11 | 165 KB    | 9          |  10%
# anaconda-client-1.11 | 165 KB    | #######7   |  77%
# anaconda-client-1.11 | 165 KB    | ########## | 100%
#
# requests-2.28.1      | 99 KB     |            |   0%
# requests-2.28.1      | 99 KB     | ########## | 100%
# requests-2.28.1      | 99 KB     | ########## | 100%
#
# conda-23.1.0         | 946 KB    |            |   0%
# conda-23.1.0         | 946 KB    | ##         |  20%
# conda-23.1.0         | 946 KB    | ######4    |  64%
# conda-23.1.0         | 946 KB    | ########## | 100%
# conda-23.1.0         | 946 KB    | ########## | 100%
#
# pyqt-5.15.7          | 3.7 MB    |            |   0%
# pyqt-5.15.7          | 3.7 MB    | 1          |   2%
# pyqt-5.15.7          | 3.7 MB    | #4         |  14%
# pyqt-5.15.7          | 3.7 MB    | ##4        |  24%
# pyqt-5.15.7          | 3.7 MB    | ###3       |  33%
# pyqt-5.15.7          | 3.7 MB    | ####9      |  50%
# pyqt-5.15.7          | 3.7 MB    | ######1    |  62%
# pyqt-5.15.7          | 3.7 MB    | #######3   |  73%
# pyqt-5.15.7          | 3.7 MB    | ########7  |  87%
# pyqt-5.15.7          | 3.7 MB    | #########9 | 100%
# pyqt-5.15.7          | 3.7 MB    | ########## | 100%
#
# pyjwt-2.4.0          | 38 KB     |            |   0%
# pyjwt-2.4.0          | 38 KB     | ########## | 100%
# pyjwt-2.4.0          | 38 KB     | ########## | 100%
#
# pycosat-0.6.4        | 74 KB     |            |   0%
# pycosat-0.6.4        | 74 KB     | ########## | 100%
# pycosat-0.6.4        | 74 KB     | ########## | 100%
#
# tqdm-4.64.1          | 143 KB    |            |   0%
# tqdm-4.64.1          | 143 KB    | ########## | 100%
# tqdm-4.64.1          | 143 KB    | ########## | 100%
#
# ruamel.yaml-0.17.21  | 174 KB    |            |   0%
# ruamel.yaml-0.17.21  | 174 KB    | 9          |   9%
# ruamel.yaml-0.17.21  | 174 KB    | #8         |  18%
# ruamel.yaml-0.17.21  | 174 KB    | ##7        |  28%
# ruamel.yaml-0.17.21  | 174 KB    | #######3   |  74%
# ruamel.yaml-0.17.21  | 174 KB    | ########## | 100%
# ruamel.yaml-0.17.21  | 174 KB    | ########## | 100%
#
# pcre-8.45            | 382 KB    |            |   0%
# pcre-8.45            | 382 KB    | 8          |   8%
# pcre-8.45            | 382 KB    | ####6      |  46%
# pcre-8.45            | 382 KB    | #######9   |  80%
# pcre-8.45            | 382 KB    | ########## | 100%
#
# xz-5.2.10            | 520 KB    |            |   0%
# xz-5.2.10            | 520 KB    | 3          |   3%
# xz-5.2.10            | 520 KB    | ###3       |  34%
# xz-5.2.10            | 520 KB    | ######4    |  65%
# xz-5.2.10            | 520 KB    | #########8 |  98%
# xz-5.2.10            | 520 KB    | ########## | 100%
#
# qt-main-5.15.2       | 50.0 MB   |            |   0%
# qt-main-5.15.2       | 50.0 MB   |            |   0%
# qt-main-5.15.2       | 50.0 MB   |            |   1%
# qt-main-5.15.2       | 50.0 MB   | 1          |   1%
# qt-main-5.15.2       | 50.0 MB   | 1          |   2%
# qt-main-5.15.2       | 50.0 MB   | 2          |   2%
# qt-main-5.15.2       | 50.0 MB   | 2          |   3%
# qt-main-5.15.2       | 50.0 MB   | 3          |   3%
# qt-main-5.15.2       | 50.0 MB   | 3          |   4%
# qt-main-5.15.2       | 50.0 MB   | 4          |   5%
# qt-main-5.15.2       | 50.0 MB   | 5          |   6%
# qt-main-5.15.2       | 50.0 MB   | 6          |   7%
# qt-main-5.15.2       | 50.0 MB   | 7          |   7%
# qt-main-5.15.2       | 50.0 MB   | 8          |   8%
# qt-main-5.15.2       | 50.0 MB   | 9          |   9%
# qt-main-5.15.2       | 50.0 MB   | #          |  10%
# qt-main-5.15.2       | 50.0 MB   | #1         |  11%
# qt-main-5.15.2       | 50.0 MB   | #2         |  13%
# qt-main-5.15.2       | 50.0 MB   | #3         |  14%
# qt-main-5.15.2       | 50.0 MB   | #5         |  15%
# qt-main-5.15.2       | 50.0 MB   | #6         |  16%
# qt-main-5.15.2       | 50.0 MB   | #7         |  17%
# qt-main-5.15.2       | 50.0 MB   | #9         |  19%
# qt-main-5.15.2       | 50.0 MB   | ##         |  21%
# qt-main-5.15.2       | 50.0 MB   | ##2        |  22%
# qt-main-5.15.2       | 50.0 MB   | ##3        |  23%
# qt-main-5.15.2       | 50.0 MB   | ##4        |  25%
# qt-main-5.15.2       | 50.0 MB   | ##6        |  27%
# qt-main-5.15.2       | 50.0 MB   | ##8        |  28%
# qt-main-5.15.2       | 50.0 MB   | ##9        |  30%
# qt-main-5.15.2       | 50.0 MB   | ###1       |  31%
# qt-main-5.15.2       | 50.0 MB   | ###2       |  33%
# qt-main-5.15.2       | 50.0 MB   | ###4       |  35%
# qt-main-5.15.2       | 50.0 MB   | ###6       |  36%
# qt-main-5.15.2       | 50.0 MB   | ###7       |  38%
# qt-main-5.15.2       | 50.0 MB   | ###9       |  40%
# qt-main-5.15.2       | 50.0 MB   | ####1      |  41%
# qt-main-5.15.2       | 50.0 MB   | ####2      |  43%
# qt-main-5.15.2       | 50.0 MB   | ####5      |  45%
# qt-main-5.15.2       | 50.0 MB   | ####7      |  47%
# qt-main-5.15.2       | 50.0 MB   | ####9      |  49%
# qt-main-5.15.2       | 50.0 MB   | #####1     |  51%
# qt-main-5.15.2       | 50.0 MB   | #####3     |  54%
# qt-main-5.15.2       | 50.0 MB   | #####5     |  56%
# qt-main-5.15.2       | 50.0 MB   | #####7     |  58%
# qt-main-5.15.2       | 50.0 MB   | #####9     |  60%
# qt-main-5.15.2       | 50.0 MB   | ######1    |  62%
# qt-main-5.15.2       | 50.0 MB   | ######3    |  64%
# qt-main-5.15.2       | 50.0 MB   | ######5    |  66%
# qt-main-5.15.2       | 50.0 MB   | ######8    |  68%
# qt-main-5.15.2       | 50.0 MB   | #######1   |  72%
# qt-main-5.15.2       | 50.0 MB   | #######4   |  75%
# qt-main-5.15.2       | 50.0 MB   | #######7   |  77%
# qt-main-5.15.2       | 50.0 MB   | #######9   |  79%
# qt-main-5.15.2       | 50.0 MB   | ########1  |  81%
# qt-main-5.15.2       | 50.0 MB   | ########3  |  83%
# qt-main-5.15.2       | 50.0 MB   | ########7  |  88%
# qt-main-5.15.2       | 50.0 MB   | ########9  |  90%
# qt-main-5.15.2       | 50.0 MB   | #########2 |  93%
# qt-main-5.15.2       | 50.0 MB   | #########5 |  95%
# qt-main-5.15.2       | 50.0 MB   | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | ########## | 100%
#
# lerc-3.0             | 120 KB    |            |   0%
# lerc-3.0             | 120 KB    | #####3     |  53%
# lerc-3.0             | 120 KB    | ########## | 100%
#
# libpng-1.6.37        | 333 KB    |            |   0%
# libpng-1.6.37        | 333 KB    | #9         |  19%
# libpng-1.6.37        | 333 KB    | ########## | 100%
# libpng-1.6.37        | 333 KB    | ########## | 100%
#
# packaging-22.0       | 67 KB     |            |   0%
# packaging-22.0       | 67 KB     | ########## | 100%
# packaging-22.0       | 67 KB     | ########## | 100%
#
# qt-webengine-5.15.9  | 48.9 MB   |            |   0%
# qt-webengine-5.15.9  | 48.9 MB   |            |   0%
# qt-webengine-5.15.9  | 48.9 MB   | 1          |   2%
# qt-webengine-5.15.9  | 48.9 MB   | 3          |   3%
# qt-webengine-5.15.9  | 48.9 MB   | 5          |   6%
# qt-webengine-5.15.9  | 48.9 MB   | 7          |   7%
# qt-webengine-5.15.9  | 48.9 MB   | 8          |   9%
# qt-webengine-5.15.9  | 48.9 MB   | #          |  10%
# qt-webengine-5.15.9  | 48.9 MB   | #2         |  12%
# qt-webengine-5.15.9  | 48.9 MB   | #4         |  14%
# qt-webengine-5.15.9  | 48.9 MB   | #5         |  16%
# qt-webengine-5.15.9  | 48.9 MB   | #7         |  17%
# qt-webengine-5.15.9  | 48.9 MB   | #9         |  19%
# qt-webengine-5.15.9  | 48.9 MB   | ##1        |  22%
# qt-webengine-5.15.9  | 48.9 MB   | ##3        |  23%
# qt-webengine-5.15.9  | 48.9 MB   | ##5        |  26%
# qt-webengine-5.15.9  | 48.9 MB   | ##8        |  28%
# qt-webengine-5.15.9  | 48.9 MB   | ###        |  30%
# qt-webengine-5.15.9  | 48.9 MB   | ###2       |  32%
# qt-webengine-5.15.9  | 48.9 MB   | ###4       |  34%
# qt-webengine-5.15.9  | 48.9 MB   | ###5       |  36%
# qt-webengine-5.15.9  | 48.9 MB   | ###7       |  37%
# qt-webengine-5.15.9  | 48.9 MB   | ###9       |  39%
# qt-webengine-5.15.9  | 48.9 MB   | ####1      |  42%
# qt-webengine-5.15.9  | 48.9 MB   | ####4      |  44%
# qt-webengine-5.15.9  | 48.9 MB   | ####7      |  47%
# qt-webengine-5.15.9  | 48.9 MB   | #####      |  50%
# qt-webengine-5.15.9  | 48.9 MB   | #####2     |  52%
# qt-webengine-5.15.9  | 48.9 MB   | #####5     |  56%
# qt-webengine-5.15.9  | 48.9 MB   | #####7     |  58%
# qt-webengine-5.15.9  | 48.9 MB   | #####9     |  60%
# qt-webengine-5.15.9  | 48.9 MB   | ######2    |  62%
# qt-webengine-5.15.9  | 48.9 MB   | ######5    |  65%
# qt-webengine-5.15.9  | 48.9 MB   | ######8    |  68%
# qt-webengine-5.15.9  | 48.9 MB   | #######    |  70%
# qt-webengine-5.15.9  | 48.9 MB   | #######1   |  72%
# qt-webengine-5.15.9  | 48.9 MB   | #######3   |  74%
# qt-webengine-5.15.9  | 48.9 MB   | #######5   |  76%
# qt-webengine-5.15.9  | 48.9 MB   | #######8   |  79%
# qt-webengine-5.15.9  | 48.9 MB   | ########1  |  81%
# qt-webengine-5.15.9  | 48.9 MB   | ########3  |  83%
# qt-webengine-5.15.9  | 48.9 MB   | ########4  |  85%
# qt-webengine-5.15.9  | 48.9 MB   | ########7  |  88%
# qt-webengine-5.15.9  | 48.9 MB   | #########  |  90%
# qt-webengine-5.15.9  | 48.9 MB   | #########3 |  93%
# qt-webengine-5.15.9  | 48.9 MB   | #########6 |  96%
# qt-webengine-5.15.9  | 48.9 MB   | #########8 |  98%
# qt-webengine-5.15.9  | 48.9 MB   | ########## | 100%
#
# freetype-2.12.1      | 490 KB    |            |   0%
# freetype-2.12.1      | 490 KB    | #9         |  20%
# freetype-2.12.1      | 490 KB    | ########## | 100%
# freetype-2.12.1      | 490 KB    | ########## | 100%
#
# conda-package-handli | 286 KB    |            |   0%
# conda-package-handli | 286 KB    | 5          |   6%
# conda-package-handli | 286 KB    | #1         |  11%
# conda-package-handli | 286 KB    | ##7        |  28%
# conda-package-handli | 286 KB    | #########5 |  95%
# conda-package-handli | 286 KB    | ########## | 100%
#
# lz4-c-1.9.4          | 143 KB    |            |   0%
# lz4-c-1.9.4          | 143 KB    | #1         |  11%
# lz4-c-1.9.4          | 143 KB    | ##2        |  22%
# lz4-c-1.9.4          | 143 KB    | #####6     |  56%
# lz4-c-1.9.4          | 143 KB    | ########## | 100%
# lz4-c-1.9.4          | 143 KB    | ########## | 100%
#
# tzdata-2022g         | 114 KB    |            |   0%
# tzdata-2022g         | 114 KB    | #####6     |  56%
# tzdata-2022g         | 114 KB    | ########## | 100%
#
# libwebp-base-1.2.4   | 279 KB    |            |   0%
# libwebp-base-1.2.4   | 279 KB    | #1         |  11%
# libwebp-base-1.2.4   | 279 KB    | #########1 |  92%
# libwebp-base-1.2.4   | 279 KB    | ########## | 100%
#
# pytz-2022.7          | 210 KB    |            |   0%
# pytz-2022.7          | 210 KB    | 7          |   8%
# pytz-2022.7          | 210 KB    | ##2        |  23%
# pytz-2022.7          | 210 KB    | ######1    |  61%
# pytz-2022.7          | 210 KB    | ########## | 100%
# pytz-2022.7          | 210 KB    | ########## | 100%
#
# traitlets-5.7.1      | 205 KB    |            |   0%
# traitlets-5.7.1      | 205 KB    | #5         |  16%
# traitlets-5.7.1      | 205 KB    | ########## | 100%
# traitlets-5.7.1      | 205 KB    | ########## | 100%
#
# cffi-1.15.1          | 238 KB    |            |   0%
# cffi-1.15.1          | 238 KB    | ##6        |  27%
# cffi-1.15.1          | 238 KB    | ########## | 100%
# cffi-1.15.1          | 238 KB    | ########## | 100%
#
# jupyter_core-5.1.1   | 107 KB    |            |   0%
# jupyter_core-5.1.1   | 107 KB    | #######4   |  75%
# jupyter_core-5.1.1   | 107 KB    | ########## | 100%
#
# pyrsistent-0.18.0    | 90 KB     |            |   0%
# pyrsistent-0.18.0    | 90 KB     | ###5       |  35%
# pyrsistent-0.18.0    | 90 KB     | ########## | 100%
# pyrsistent-0.18.0    | 90 KB     | ########## | 100%
#
# pip-22.3.1           | 2.7 MB    |            |   0%
# pip-22.3.1           | 2.7 MB    | 2          |   2%
# pip-22.3.1           | 2.7 MB    | #          |  11%
# pip-22.3.1           | 2.7 MB    | ##         |  21%
# pip-22.3.1           | 2.7 MB    | ##9        |  30%
# pip-22.3.1           | 2.7 MB    | ####       |  40%
# pip-22.3.1           | 2.7 MB    | #####5     |  56%
# pip-22.3.1           | 2.7 MB    | ######8    |  68%
# pip-22.3.1           | 2.7 MB    | #######9   |  80%
# pip-22.3.1           | 2.7 MB    | #########9 |  99%
# pip-22.3.1           | 2.7 MB    | ########## | 100%
#
# gst-plugins-base-1.1 | 1.7 MB    |            |   0%
# gst-plugins-base-1.1 | 1.7 MB    | 4          |   5%
# gst-plugins-base-1.1 | 1.7 MB    | ##8        |  28%
# gst-plugins-base-1.1 | 1.7 MB    | #####5     |  55%
# gst-plugins-base-1.1 | 1.7 MB    | ########1  |  82%
# gst-plugins-base-1.1 | 1.7 MB    | ########## | 100%
#
# libwebp-1.2.4        | 67 KB     |            |   0%
# libwebp-1.2.4        | 67 KB     | ##3        |  24%
# libwebp-1.2.4        | 67 KB     | ####7      |  48%
# libwebp-1.2.4        | 67 KB     | ########## | 100%
# libwebp-1.2.4        | 67 KB     | ########## | 100%
#
# libiconv-1.16        | 651 KB    |            |   0%
# libiconv-1.16        | 651 KB    | ##9        |  29%
# libiconv-1.16        | 651 KB    | ########6  |  86%
# libiconv-1.16        | 651 KB    | ########## | 100%
#
# pyyaml-6.0           | 145 KB    |            |   0%
# pyyaml-6.0           | 145 KB    | ########## | 100%
# pyyaml-6.0           | 145 KB    | ########## | 100%
#
# gstreamer-1.18.5     | 1.7 MB    |            |   0%
# gstreamer-1.18.5     | 1.7 MB    | 6          |   6%
# gstreamer-1.18.5     | 1.7 MB    | ##5        |  26%
# gstreamer-1.18.5     | 1.7 MB    | ###9       |  40%
# gstreamer-1.18.5     | 1.7 MB    | #####4     |  55%
# gstreamer-1.18.5     | 1.7 MB    | ########## | 100%
# gstreamer-1.18.5     | 1.7 MB    | ########## | 100%
#
# libvorbis-1.3.7      | 202 KB    |            |   0%
# libvorbis-1.3.7      | 202 KB    | ######3    |  63%
# libvorbis-1.3.7      | 202 KB    | ########## | 100%
#
# clyent-1.2.2         | 21 KB     |            |   0%
# clyent-1.2.2         | 21 KB     | #######5   |  75%
# clyent-1.2.2         | 21 KB     | ########## | 100%
# clyent-1.2.2         | 21 KB     | ########## | 100%
#
# zstd-1.5.2           | 509 KB    |            |   0%
# zstd-1.5.2           | 509 KB    | #5         |  16%
# zstd-1.5.2           | 509 KB    | #####3     |  53%
# zstd-1.5.2           | 509 KB    | ########1  |  82%
# zstd-1.5.2           | 509 KB    | ########## | 100%
#
# chardet-4.0.0        | 212 KB    |            |   0%
# chardet-4.0.0        | 212 KB    | 7          |   8%
# chardet-4.0.0        | 212 KB    | ########## | 100%
# chardet-4.0.0        | 212 KB    | ########## | 100%
#
# jsonschema-4.16.0    | 143 KB    |            |   0%
# jsonschema-4.16.0    | 143 KB    | ###3       |  33%
# jsonschema-4.16.0    | 143 KB    | ########## | 100%
# jsonschema-4.16.0    | 143 KB    | ########## | 100%
#
# qtwebkit-5.212       | 10.3 MB   |            |   0%
# qtwebkit-5.212       | 10.3 MB   |            |   0%
# qtwebkit-5.212       | 10.3 MB   |            |   0%
# qtwebkit-5.212       | 10.3 MB   | 2          |   3%
# qtwebkit-5.212       | 10.3 MB   | 4          |   5%
# qtwebkit-5.212       | 10.3 MB   | 6          |   6%
# qtwebkit-5.212       | 10.3 MB   | 8          |   9%
# qtwebkit-5.212       | 10.3 MB   | #          |  10%
# qtwebkit-5.212       | 10.3 MB   | #2         |  12%
# qtwebkit-5.212       | 10.3 MB   | #4         |  15%
# qtwebkit-5.212       | 10.3 MB   | #8         |  19%
# qtwebkit-5.212       | 10.3 MB   | ##1        |  22%
# qtwebkit-5.212       | 10.3 MB   | ##4        |  24%
# qtwebkit-5.212       | 10.3 MB   | ##6        |  27%
# qtwebkit-5.212       | 10.3 MB   | ##9        |  29%
# qtwebkit-5.212       | 10.3 MB   | ###2       |  32%
# qtwebkit-5.212       | 10.3 MB   | ###5       |  36%
# qtwebkit-5.212       | 10.3 MB   | ###9       |  39%
# qtwebkit-5.212       | 10.3 MB   | ####2      |  43%
# qtwebkit-5.212       | 10.3 MB   | ####7      |  47%
# qtwebkit-5.212       | 10.3 MB   | #####      |  51%
# qtwebkit-5.212       | 10.3 MB   | #####5     |  56%
# qtwebkit-5.212       | 10.3 MB   | #####9     |  60%
# qtwebkit-5.212       | 10.3 MB   | ######6    |  67%
# qtwebkit-5.212       | 10.3 MB   | #######1   |  71%
# qtwebkit-5.212       | 10.3 MB   | #######6   |  77%
# qtwebkit-5.212       | 10.3 MB   | ########2  |  82%
# qtwebkit-5.212       | 10.3 MB   | ########7  |  88%
# qtwebkit-5.212       | 10.3 MB   | #########2 |  93%
# qtwebkit-5.212       | 10.3 MB   | #########7 |  98%
# qtwebkit-5.212       | 10.3 MB   | ########## | 100%
#
# navigator-updater-0. | 2.2 MB    |            |   0%
# navigator-updater-0. | 2.2 MB    | 8          |   9%
# navigator-updater-0. | 2.2 MB    | ###1       |  32%
# navigator-updater-0. | 2.2 MB    | ####9      |  49%
# navigator-updater-0. | 2.2 MB    | ########5  |  85%
# navigator-updater-0. | 2.2 MB    | ########## | 100%
#
# cryptography-38.0.4  | 1.0 MB    |            |   0%
# cryptography-38.0.4  | 1.0 MB    | #2         |  12%
# cryptography-38.0.4  | 1.0 MB    | ######7    |  68%
# cryptography-38.0.4  | 1.0 MB    | ########## | 100%
#
# nbformat-5.7.0       | 152 KB    |            |   0%
# nbformat-5.7.0       | 152 KB    | ######3    |  63%
# nbformat-5.7.0       | 152 KB    | ########## | 100%
#
# conda-package-stream | 27 KB     |            |   0%
# conda-package-stream | 27 KB     | ########## | 100%
# conda-package-stream | 27 KB     | ########## | 100%
#
# pathlib-1.0.1        | 17 KB     |            |   0%
# pathlib-1.0.1        | 17 KB     | ########## | 100%
# pathlib-1.0.1        | 17 KB     | ########## | 100%
#
# conda-content-trust- | 86 KB     |            |   0%
# conda-content-trust- | 86 KB     | #8         |  19%
# conda-content-trust- | 86 KB     | ###7       |  37%
# conda-content-trust- | 86 KB     | ########## | 100%
# conda-content-trust- | 86 KB     | ########## | 100%
#
# toml-0.10.2          | 20 KB     |            |   0%
# toml-0.10.2          | 20 KB     | ########## | 100%
# toml-0.10.2          | 20 KB     | ########## | 100%
#
# libclang-12.0.0      | 17.8 MB   |            |   0%
# libclang-12.0.0      | 17.8 MB   |            |   1%
# libclang-12.0.0      | 17.8 MB   | 3          |   3%
# libclang-12.0.0      | 17.8 MB   | 5          |   5%
# libclang-12.0.0      | 17.8 MB   | 8          |   8%
# libclang-12.0.0      | 17.8 MB   | #1         |  11%
# libclang-12.0.0      | 17.8 MB   | #4         |  14%
# libclang-12.0.0      | 17.8 MB   | #6         |  17%
# libclang-12.0.0      | 17.8 MB   | ##1        |  21%
# libclang-12.0.0      | 17.8 MB   | ##4        |  24%
# libclang-12.0.0      | 17.8 MB   | ##7        |  28%
# libclang-12.0.0      | 17.8 MB   | ###1       |  32%
# libclang-12.0.0      | 17.8 MB   | ###5       |  35%
# libclang-12.0.0      | 17.8 MB   | ###8       |  39%
# libclang-12.0.0      | 17.8 MB   | ####2      |  43%
# libclang-12.0.0      | 17.8 MB   | ####7      |  47%
# libclang-12.0.0      | 17.8 MB   | #####1     |  52%
# libclang-12.0.0      | 17.8 MB   | #####5     |  56%
# libclang-12.0.0      | 17.8 MB   | #####9     |  60%
# libclang-12.0.0      | 17.8 MB   | ######5    |  66%
# libclang-12.0.0      | 17.8 MB   | #######    |  70%
# libclang-12.0.0      | 17.8 MB   | #######4   |  75%
# libclang-12.0.0      | 17.8 MB   | #######8   |  79%
# libclang-12.0.0      | 17.8 MB   | ########3  |  84%
# libclang-12.0.0      | 17.8 MB   | ########7  |  88%
# libclang-12.0.0      | 17.8 MB   | #########2 |  92%
# libclang-12.0.0      | 17.8 MB   | #########6 |  97%
# libclang-12.0.0      | 17.8 MB   | ########## | 100%
#
# pyqt5-sip-12.11.0    | 75 KB     |            |   0%
# pyqt5-sip-12.11.0    | 75 KB     | ##1        |  21%
# pyqt5-sip-12.11.0    | 75 KB     | ####2      |  43%
# pyqt5-sip-12.11.0    | 75 KB     | ########5  |  85%
# pyqt5-sip-12.11.0    | 75 KB     | ########## | 100%
#
# libtiff-4.5.0        | 1.2 MB    |            |   0%
# libtiff-4.5.0        | 1.2 MB    | ##5        |  25%
# libtiff-4.5.0        | 1.2 MB    | ######5    |  66%
# libtiff-4.5.0        | 1.2 MB    | ########## | 100%
# libtiff-4.5.0        | 1.2 MB    | ########## | 100%
#
# pywin32-305          | 10.7 MB   |            |   0%
# pywin32-305          | 10.7 MB   | 2          |   2%
# pywin32-305          | 10.7 MB   | 5          |   6%
# pywin32-305          | 10.7 MB   | 8          |   8%
# pywin32-305          | 10.7 MB   | #7         |  17%
# pywin32-305          | 10.7 MB   | ##         |  20%
# pywin32-305          | 10.7 MB   | ###1       |  31%
# pywin32-305          | 10.7 MB   | ###9       |  39%
# pywin32-305          | 10.7 MB   | ####5      |  46%
# pywin32-305          | 10.7 MB   | #####4     |  54%
# pywin32-305          | 10.7 MB   | ######     |  61%
# pywin32-305          | 10.7 MB   | ######8    |  68%
# pywin32-305          | 10.7 MB   | #######5   |  75%
# pywin32-305          | 10.7 MB   | ########2  |  82%
# pywin32-305          | 10.7 MB   | ########9  |  89%
# pywin32-305          | 10.7 MB   | #########5 |  96%
# pywin32-305          | 10.7 MB   | ########## | 100%
#
# libxslt-1.1.35       | 407 KB    |            |   0%
# libxslt-1.1.35       | 407 KB    | ##7        |  28%
# libxslt-1.1.35       | 407 KB    | #########4 |  94%
# libxslt-1.1.35       | 407 KB    | ########## | 100%
#
# qtpy-2.2.0           | 106 KB    |            |   0%
# qtpy-2.2.0           | 106 KB    | ########## | 100%
# qtpy-2.2.0           | 106 KB    | ########## | 100%
#
# zstandard-0.18.0     | 310 KB    |            |   0%
# zstandard-0.18.0     | 310 KB    | #########8 |  98%
# zstandard-0.18.0     | 310 KB    | ########## | 100%
#
# setuptools-65.6.3    | 1.1 MB    |            |   0%
# setuptools-65.6.3    | 1.1 MB    | ##5        |  26%
# setuptools-65.6.3    | 1.1 MB    | #########4 |  94%
# setuptools-65.6.3    | 1.1 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge cudatoolkit=11.2 cudnn=8.1.0
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
